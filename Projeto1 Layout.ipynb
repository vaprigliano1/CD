# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# VICTOR APRIGLIANO
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os
from numpy import arange

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# /Users/victoraprigliano/Desktop

# %%
info13 = pd.read_csv('DOM2013.csv',sep=',')
info13.UF = info13.UF.astype('category')
info13.V0220 = info13.V0220.astype('category')
info13.V0220.cat.categories = (['Sim', 'Não'])
info13.V0231 = info13.V0231.astype('category')
info13.V0231.cat.categories = (['Sim', 'Não'])
info13.V0232 = info13.V0232.astype('category')
info13.V0232.cat.categories = (['Sim', 'Não'])
info13.V02322 = info13.V02322.astype('category')
info13.V02322.cat.categories = (['Sim', 'Não'])
info13.V02424 = info13.V02424.astype('category')
info13.V02424.cat.categories = (['Sim', 'Não'])
info13.V02426 = info13.V02426.astype('category')
info13.V02426.cat.categories = (['Sim', 'Não'])
info13.V02425 = info13.V02425.astype('category')
info13.V02425.cat.categories = (['Sim', 'Não'])
#info13.V4622 = info13.V4622.astype('category')
#info13.V4622.cat.categories = ([ 'Sem','Até 1/4', 'Até 1/2','Até 1','Até 2','Até 3'])

#Estados selecionados : SP(2 mais desenvolvido) e Maranhão (Menos desenvolvido), Area escolhida: todas menos grandes centros urbanos. Renda: Até 3 salarios minimos.  
f = info13[(info13.UF==22)&(info13.V4622<=5)&(info13.V4105>=2)|(info13.UF==35)&(info13.V4622<=5) & (info13.V4105>=2)].loc[:,['UF','V0220','V0231','V02322','V02424','V02426','V02425','V4622','V4105']]
f.columns=["ESTADO","CELULAR","MICROCUMPUTADOR",'ACESSO INTERNET',"3G/4G","BANDA LARGA","CONEXÃO DISCADA","RENDA","ÁREA"]
f.head()

writer = pd.ExcelWriter('tabela13.xlsx', engine='xlsxwriter')
f.to_excel(writer, sheet_name='Projeto1_13')
writer.save()

f
# Out:
#        ESTADO CELULAR MICROCUMPUTADOR ACESSO INTERNET 3G/4G BANDA LARGA  \
# 24426      22     Sim             Não             Não   NaN         NaN
# 24427      22     Sim             Não             Não   NaN         NaN
# 24428      22     Sim             Não             Não   NaN         NaN
# 24430      22     Não             Não             Não   NaN         NaN
# 24431      22     Sim             Não             Não   NaN         NaN
# 24432      22     Sim             Não             Não   NaN         NaN
# 24433      22     Sim             Não             Não   NaN         NaN
# 24434      22     Sim             Não             Não   NaN         NaN
# 24435      22     Não             Não             Não   NaN         NaN
# 24436      22     Sim             Não             Não   NaN         NaN
# 24437      22     Sim             Não             Não   NaN         NaN
# 24439      22     Sim             Não             Não   NaN         NaN
# 24441      22     Não             Não             Não   NaN         NaN
# 24442      22     Sim             Não             Não   NaN         NaN
# 24461      22     Não             Não             Não   NaN         NaN
# 24462      22     Sim             Não             Não   NaN         NaN
# 24465      22     Sim             Não             Não   NaN         NaN
# 24468      22     Sim             Não             Não   NaN         NaN
# 24469      22     Sim             Não             Não   NaN         NaN
# 24470      22     Sim             Não             Não   NaN         NaN
# 24471      22     Sim             Não             Não   NaN         NaN
# 24473      22     Não             Não             Não   NaN         NaN
# 24475      22     Sim             Não             Não   NaN         NaN
# 24476      22     Sim             Sim             Sim   Não         Sim
# 24477      22     Sim             Não             Sim   Sim         Sim
# 24478      22     Sim             Não             Não   NaN         NaN
# 24480      22     Sim             Não             Não   NaN         NaN
# 24481      22     Sim             Não             Não   NaN         NaN
# 24482      22     Sim             Não             Não   NaN         NaN
# 24483      22     Sim             Não             Não   NaN         NaN
# ...       ...     ...             ...             ...   ...         ...
# 108265     35     Sim             Sim             Sim   Não         Sim
# 108266     35     Sim             Sim             Sim   Não         Sim
# 108267     35     Sim             Sim             Sim   Não         Sim
# 108268     35     Sim             Sim             Sim   Não         Sim
# 108270     35     Sim             Sim             Sim   Não         Sim
# 108271     35     Sim             Sim             Sim   Sim         Não
# 108273     35     Sim             Sim             Sim   Não         Sim
# 108278     35     Sim             Não             Não   NaN         NaN
# 108279     35     Sim             Não             Não   NaN         NaN
# 108282     35     Sim             Sim             Sim   Não         Sim
# 108285     35     Sim             Não             Sim   Não         Sim
# 108288     35     Sim             Sim             Sim   Não         Sim
# 108292     35     Sim             Sim             Sim   Não         Sim
# 108470     35     Sim             Sim             Sim   Sim         Não
# 108471     35     Sim             Não             Não   NaN         NaN
# 108472     35     Sim             Sim             Sim   Não         Sim
# 108473     35     Sim             Sim             Sim   Sim         Não
# 108474     35     Sim             Não             Não   NaN         NaN
# 108475     35     Sim             Não             Não   NaN         NaN
# 108476     35     Sim             Sim             Sim   Sim         Não
# 108477     35     Sim             Não             Não   NaN         NaN
# 108478     35     Sim             Sim             Sim   Sim         Não
# 108479     35     Sim             Não             Não   NaN         NaN
# 108480     35     Sim             Não             Não   NaN         NaN
# 108481     35     Sim             Não             Não   NaN         NaN
# 108482     35     Sim             Não             Não   NaN         NaN
# 108483     35     Sim             Não             Não   NaN         NaN
# 108484     35     Sim             Sim             Sim   Sim         Não
# 108486     35     Sim             Não             Não   NaN         NaN
# 108487     35     Sim             Não             Não   NaN         NaN
#
#        CONEXÃO DISCADA  RENDA  ÁREA
# 24426              NaN    4.0     8
# 24427              NaN    3.0     8
# 24428              NaN    4.0     8
# 24430              NaN    4.0     8
# 24431              NaN    2.0     8
# 24432              NaN    2.0     8
# 24433              NaN    3.0     8
# 24434              NaN    4.0     8
# 24435              NaN    2.0     8
# 24436              NaN    1.0     8
# 24437              NaN    4.0     8
# 24439              NaN    2.0     8
# 24441              NaN    2.0     8
# 24442              NaN    3.0     8
# 24461              NaN    4.0     8
# 24462              NaN    1.0     8
# 24465              NaN    3.0     8
# 24468              NaN    3.0     8
# 24469              NaN    2.0     8
# 24470              NaN    1.0     8
# 24471              NaN    2.0     8
# 24473              NaN    1.0     8
# 24475              NaN    3.0     8
# 24476              Não    1.0     8
# 24477              Não    1.0     8
# 24478              NaN    1.0     8
# 24480              NaN    2.0     8
# 24481              NaN    1.0     8
# 24482              NaN    4.0     8
# 24483              NaN    3.0     8
# ...                ...    ...   ...
# 108265             Não    3.0     2
# 108266             Não    4.0     2
# 108267             Não    5.0     2
# 108268             Não    3.0     2
# 108270             Não    4.0     2
# 108271             Não    3.0     2
# 108273             Não    4.0     2
# 108278             NaN    2.0     2
# 108279             NaN    3.0     2
# 108282             Não    5.0     2
# 108285             Não    3.0     2
# 108288             Não    5.0     2
# 108292             Não    4.0     2
# 108470             Não    4.0     8
# 108471             NaN    2.0     8
# 108472             Sim    4.0     8
# 108473             Não    2.0     8
# 108474             NaN    1.0     8
# 108475             NaN    1.0     8
# 108476             Não    3.0     8
# 108477             NaN    4.0     8
# 108478             Não    4.0     8
# 108479             NaN    4.0     8
# 108480             NaN    5.0     8
# 108481             NaN    4.0     8
# 108482             NaN    3.0     8
# 108483             NaN    5.0     8
# 108484             Não    4.0     8
# 108486             NaN    3.0     8
# 108487             NaN    4.0     8
#
# [1177 rows x 9 columns]

# %%
#renda domiciliar

# %%
info14=pd.read_csv('DOM2014.csv',sep=',')
info14.UF = info14.UF.astype('category')
info14.V0220 = info14.V0220.astype('category')
info14.V0220.cat.categories = (['Sim', 'Não'])
info14.V0231 = info14.V0231.astype('category')
info14.V0231.cat.categories = (['Sim', 'Não'])
info14.V0232 = info14.V0232.astype('category')
info14.V0232.cat.categories = (['Sim', 'Não'])
info14.V02322 = info14.V02322.astype('category')
info14.V02322.cat.categories = (['Sim', 'Não'])
info14.V02424 = info14.V02424.astype('category')
info14.V02424.cat.categories = (['Sim', 'Não'])
info14.V02426 = info14.V02426.astype('category')
info14.V02426.cat.categories = (['Sim', 'Não'])
info14.V02425 = info14.V02425.astype('category')
info14.V02425.cat.categories = (['Sim', 'Não'])
#info14.V4622 = info14.V4622.astype('category')
#info14.V4622.cat.categories = ([ 'Sem','Até 1/4', 'Até 1/2','Até 1','Até 2','Até 3'])

#Estados selecionados : SP(2 mais desenvolvido) e Maranhão (Menos desenvolvido), Area escolhida: todas menos grandes centros urbanos. Renda: Até 3 salarios minimos.  
f2 = info14[(info14.UF==22)&(info14.V4622<=5)&(info14.V4105>=2)|(info14.UF==35)&(info14.V4622<=5) & (info14.V4105>=2)].loc[:,['UF','V0220','V0231','V02322','V02424','V02426','V02425','V4622','V4105']]
f2.columns=["ESTADO","CELULAR","MICROCUMPUTADOR",'ACESSO INTERNET',"3G/4G","BANDA LARGA","CONEXÃO DISCADA","RENDA","ÁREA"]
f2.head()

writer2 = pd.ExcelWriter('tabela14.xlsx', engine='xlsxwriter')
f2.to_excel(writer2, sheet_name='Projeto1_14')
writer2.save()

# %%
#Se usar o arquivo descompactado
info15 = pd.read_csv('DOM2015.csv',sep=',')
info15.UF = info15.UF.astype('category')
info15.V0220 = info15.V0220.astype('category')
info15.V0220.cat.categories = (['Sim', 'Não'])
info15.V0231 = info15.V0231.astype('category')
info15.V0231.cat.categories = (['Sim', 'Não'])
info15.V0232 = info15.V0232.astype('category')
info15.V0232.cat.categories = (['Sim', 'Não'])
info15.V02322 = info15.V02322.astype('category')
info15.V02322.cat.categories = (['Sim', 'Não'])
info15.V02424 = info15.V02424.astype('category')
info15.V02424.cat.categories = (['Sim', 'Não'])
info15.V02426 = info15.V02426.astype('category')
info15.V02426.cat.categories = (['Sim', 'Não'])
info15.V02425 = info15.V02425.astype('category')
info15.V02425.cat.categories = (['Sim', 'Não'])
#info15.V4622 = info15.V4622.astype('category')
#info15.V4622.cat.categories = ([ 'Sem','Até 1/4', 'Até 1/2','Até 1','Até 2','Até 3'])

#Estados selecionados : SP(2 mais desenvolvido) e Maranhão (Menos desenvolvido), Area escolhida: todas menos grandes centros urbanos. Renda: Até 3 salarios minimos.  
f3 = info15[(info15.UF==22)&(info15.V4622<=5)&(info15.V4105>=2)|(info15.UF==35)&(info15.V4622<=5) & (info15.V4105>=2)].loc[:,['UF','V0220','V0231','V02322','V02424','V02426','V02425','V4622','V4105']]
f3.columns=["ESTADO","CELULAR","MICROCUMPUTADOR",'ACESSO INTERNET',"3G/4G","BANDA LARGA","CONEXÃO DISCADA","RENDA","ÁREA"]
f3.head()

writer3 = pd.ExcelWriter('tabela15.xlsx', engine='xlsxwriter')
f3.to_excel(writer3, sheet_name='Projeto1_15')
writer3.save()
#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
#frequencias relativas
f.RENDA.describe()
faixa1 = arange(0,6,1)

# %%
f2.RENDA[info14.UF==22].describe()
faixa2 = arange(0,6,1)

# %%
f3.RENDA[info15.UF==22].describe()
faixa3 = arange (0,6,1)

# %%
#GRAFICOS DOS 3 ANOS EM RELAÇÃO AO ACESSO DE INTERNET
print("Acesso a internet em domicílio")
fig = plt.figure(figsize=(8,3))
g13m =(info13[info13.UF == 22].V02322.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm = g13m.plot(kind='pie',title='Maranhão 2013',autopct='%.1f')

g13sp = (info13[info13.UF == 35].V02322.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp = g13sp.plot(kind='pie',title='São Paulo 2013',autopct='%.1f')

#g13am = (info13[info13.UF == 13].V02322.value_counts(sort=False, normalize=True)*100).round(decimals=2)
#plt.subplot(143)
#plotsp = g13am.plot(kind='pie',title='Amazonas 2013',autopct='%.1f')

#g13rgs = (info13[info13.UF == 43].V02322.value_counts(sort=False, normalize=True)*100).round(decimals=2)
#plt.subplot(144)
#plotsp = g13rgs.plot(kind='pie',title='Rio Grande do Sul 2013',autopct='%.1f')
plt.show()

#-----------------------------------2014----------------------------------------------
fig = plt.figure(figsize=(8,3))
g14m =(info14[info14.UF == 22].V02322.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm = g14m.plot(kind='pie',title='Maranhão 2014',autopct='%.1f')

g14sp = (info14[info14.UF == 35].V02322.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp = g14sp.plot(kind='pie',title='São Paulo 2014',autopct='%.1f')

plt.show()

#-----------------------------------2015----------------------------------------------
fig = plt.figure(figsize=(8,3))
g15m =(info15[info15.UF == 22].V02322.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm = g15m.plot(kind='pie',title='Maranhão 2015',autopct='%.1f')

g15sp = (info15[info15.UF == 35].V02322.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp = g15sp.plot(kind='pie',title='São Paulo 2015',autopct='%.1f')

plt.show()
# Out:
# Acesso a internet em domicílio

# %%
#POSSUEM CELULAR
print ("Possuem Celular")
fig = plt.figure(figsize=(8, 3))
g13m2 =(info13[info13.UF == 22].V0220.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm2 = g13m2.plot(kind='pie',title='Maranhão 2013',autopct='%.1f')

g13sp2 = (info13[info13.UF == 35].V0220.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp2 = g13sp2.plot(kind='pie',title='São Paulo 2013',autopct='%.1f')


plt.show()
#-----------------------------------2014----------------------------------------------

fig = plt.figure(figsize=(8, 3))
g14m2 =(info14[info14.UF == 22].V0220.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm2 = g14m2.plot(kind='pie',title='Maranhão 2014',autopct='%.1f')

g14sp2 = (info14[info14.UF == 35].V0220.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp2 = g14sp2.plot(kind='pie',title='São Paulo 2014',autopct='%.1f')


plt.show()
#-----------------------------------2015----------------------------------------------

fig = plt.figure(figsize=(8, 3))
g15m2 =(info15[info15.UF == 22].V0220.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm2 = g15m2.plot(kind='pie',title='Maranhão 2015',autopct='%.1f')

g15sp2 = (info15[info15.UF == 35].V0220.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp2 = g15sp2.plot(kind='pie',title='São Paulo 2015',autopct='%.1f')


plt.show()
# Out:
# Possuem Celular

# %%
#utiliza o celular para acessar a internet
fig = plt.figure(figsize=(8, 3))
g13m3 =(info13[info13.UF == 22].V02424.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm3 = g13m3.plot(kind='pie',title='Maranhão 2013',autopct='%.1f')

g13sp3 = (info13[info13.UF == 35].V02424.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp3 = g13sp3.plot(kind='pie',title='São Paulo 2013',autopct='%.1f')
#-----------------------------------2014---------------------------------------
fig = plt.figure(figsize=(8, 3))
g14m3 =(info14[info14.UF == 22].V02424.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm3 = g14m3.plot(kind='pie',title='Maranhão 2014',autopct='%.1f')

g14sp3 = (info14[info14.UF == 35].V02424.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp3 = g14sp3.plot(kind='pie',title='São Paulo 2014',autopct='%.1f')
#-----------------------------------2015---------------------------------------
fig = plt.figure(figsize=(8, 3))
g15m3 =(info15[info15.UF == 22].V02424.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(121) #1 linha 2coluna 1 posição
plotm3 = g15m3.plot(kind='pie',title='Maranhão 2015',autopct='%.1f')

g15sp3 = (info15[info15.UF == 35].V02424.value_counts(sort=False, normalize=True)*100).round(decimals=2)
plt.subplot(122)
plotsp3 = g15sp3.plot(kind='pie',title='São Paulo 2015',autopct='%.1f')


plt.show()

# %%
#histograma 2013
plot = f.RENDA[info13.UF==22].plot.hist(bins=faixa1,title='HISTOGRAMA - MARANHÃO 2013',figsize=(4, 4), normed=1, alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('renda renda domiciliar per capita')
plt.show()

#histograma 2014
plot2 = f2.RENDA[info14.UF==22].plot.hist(bins=faixa2,title='HISTOGRAMA - MARANHÃO 2014',figsize=(4, 4), normed=1,color = "red", alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('renda renda domiciliar per capita')
plt.show()

#histograma 2015
plot3 = f3.RENDA[info15.UF==22].plot.hist(bins=faixa1,title='HISTOGRAMA - MARANHÃO 2015',figsize=(4, 4), normed=1,color = "green", alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('renda domiciliar per capita ')
plt.show()

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
